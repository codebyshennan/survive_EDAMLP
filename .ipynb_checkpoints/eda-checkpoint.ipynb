# %% [markdown]
# ## Objectives
#
# The objective is to predict the survival of coronary artery disease patients using the dataset provided to help doctors to formulate preemptive medical treatments. In your submission, you are to evaluate at least 3 suitable models for estimating the patients’ survivals.
#
# ## Dataset description
#
# The dataset contains the medical records of coronary artery disease patients for a particular hospital. Do note that there could be synthetic features in the dataset. Hence, please ensure that you state and verify any assumptions that you make.

# %% [markdown]
# ## Broad Strategy
#
# The aim is to identify factors that contribute greatly to the determination of the survival of patients. Understanding the key contributing factors can help doctors determine which trait ("features") to arrest in their prognosis.
#
# Our data strategy is as follows:
#
# 1. Analyse data in general (understanding the dataset) - We will have a broad overview of the data provided and make intuitive assumptions about the potential causality of each feature.
#
# 2. It is likely that data imputation is required to top up any missing data and clean up any false representation. This will form the majority of our data organisation so that analysis can be undistracted.
#     a. if the missing data is minimal in count, we shall inpute by commonality.
#     b. if the missing data is substantial, or comprise a significant proportion of the feature, we shall inpute by randomising across a range between the established feature mean +- standard deviation of the distribution.
#
# 3. In order for a clean machine learning process, we will need to convert any continuous data into numerical categories. This allows proper labelling and clear categorisation. We should ensure that the data is segregated equivocably to prevent clear majority bias during training.
#
# 4. Once our data is cleaned and organised, we can then derive assumptions - e.g. some features are not really helpful
# Group continuous data types into discrete categories e.g. age banding
#
# Feature engineering
# ML

# %% [markdown]
# ### Base Installation

# %%
# !pip3 install SQLAlchemy
# Out:
# Requirement already satisfied: SQLAlchemy in c:\users\wongs\anaconda3\lib\site-packages (1.3.20)

# %% [markdown]
# ### Base Imports
# We require a few libraries to assist us in setting up the dataframe of the data.

# %%
# linear algebra
import numpy as np 

# data processing
import pandas as pd
pd.options.mode.chained_assignment = None  # default='warn'

# data visualization
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt
from matplotlib import style

# sql
import sqlalchemy as sql

# %% [markdown]
# ### Algos

# %%
# Algorithms
from sklearn import linear_model
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC, LinearSVC
from sklearn.naive_bayes import GaussianNB

# %% [markdown]
# ### Connecting to the datasource
# Initialize the db by declaring file location.

# %%
connection_string = "sqlite:///data/survive.db"

# %%
# echoes the search params at every connection
db = sql.create_engine(connection_string, echo=True)
engine = db.connect()
# Out:
# 2022-01-17 03:14:34,903 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2022-01-17 03:14:34,903 INFO sqlalchemy.engine.base.Engine ()
# 2022-01-17 03:14:34,908 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2022-01-17 03:14:34,909 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# ### Splitting the data into training and testing data

# %%
from sklearn.model_selection import train_test_split

query_all = "SELECT * FROM survive"
df = pd.read_sql(query_all, engine)
train, test = train_test_split(df, test_size=0.2)
# Out:
# 2022-01-17 03:14:35,864 INFO sqlalchemy.engine.base.Engine PRAGMA main.table_info("SELECT * FROM survive")
# 2022-01-17 03:14:35,865 INFO sqlalchemy.engine.base.Engine ()
# 2022-01-17 03:14:35,869 INFO sqlalchemy.engine.base.Engine PRAGMA temp.table_info("SELECT * FROM survive")
# 2022-01-17 03:14:35,870 INFO sqlalchemy.engine.base.Engine ()
# 2022-01-17 03:14:35,872 INFO sqlalchemy.engine.base.Engine SELECT * FROM survive
# 2022-01-17 03:14:35,873 INFO sqlalchemy.engine.base.Engine ()

# %% [markdown]
# ### Data Exploration/Analysis

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12000 entries, 11506 to 11554
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   ID                      12000 non-null  object
#  1   Survive                 12000 non-null  object
#  2   Gender                  12000 non-null  object
#  3   Smoke                   12000 non-null  object
#  4   Diabetes                12000 non-null  object
#  5   Age                     12000 non-null  int64
#  6   Ejection Fraction       12000 non-null  object
#  7   Sodium                  12000 non-null  int64
#  8   Creatinine              11599 non-null  float64
#  9   Platelets               12000 non-null  float64
#  10  Creatine phosphokinase  12000 non-null  int64
#  11  Blood Pressure          12000 non-null  int64
#  12  Hemoglobin              12000 non-null  float64
#  13  Height                  12000 non-null  int64
#  14  Weight                  12000 non-null  int64
#  15  Favorite color          12000 non-null  object
# dtypes: float64(3), int64(6), object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# There are 12000 training samples and 14 features, with the target variable ("Survive"). 6 of the above features are integers, with the rest being floats or objects. The breakdown of the features follows after exploratory analysis of the features in detail.

# %%
train.head(10)
# Out:
#            ID Survive  Gender Smoke      Diabetes  Age Ejection Fraction  \
# 11506  UIUR36       1  Female   Yes  Pre-diabetes   50               Low
# 1001   UAHHVU       0    Male    No        Normal   70               Low
# 10417  GS5S2W      No    Male    No        Normal   64            Normal
# 582    PAG8AH       0  Female    No  Pre-diabetes   65            Normal
# 2174   DQU4HO       0    Male   Yes  Pre-diabetes   70               Low
# 7517   FL7YTV       1    Male    No        Normal   60               Low
# 8132   5SKBNY       0  Female    No        Normal   46               Low
# 10439  ZJ0K1N       1  Female   Yes        Normal   72               Low
# 2268   RC5TYS       0    Male   Yes  Pre-diabetes   65               Low
# 12717  5EZ77Q       0    Male   YES  Pre-diabetes   65               Low
#
#        Sodium  Creatinine  Platelets  Creatine phosphokinase  Blood Pressure  \
# 11506     136         1.2   153000.0                     124             143
# 1001      132         1.2   173000.0                     232             113
# 10417     137         1.0   242000.0                    1610              43
# 582       140         0.9   203000.0                     113             165
# 2174      136         1.0   389000.0                     212             139
# 7517      134         3.7   217000.0                     582              77
# 8132      140         0.9   348000.0                     291              65
# 10439     138         1.7   621000.0                     328             155
# 2268      136         1.3   249000.0                     582              41
# 12717     136         1.3   249000.0                     582              94
#
#        Hemoglobin  Height  Weight Favorite color
# 11506        15.2     142      74          white
# 1001         12.8     143      39          black
# 10417        17.0     176      89           blue
# 582          10.2     140      60          white
# 2174         15.1     134      38           blue
# 7517         14.3     145      64           blue
# 8132         10.2     147      63          black
# 10439        11.7     141      62           blue
# 2268         13.0     151      43            red
# 12717        12.8     143      38         yellow

# %% [markdown]
# The data type tells us immediately that our key feature "Survive" is not present due to non-integer type ("object"). We will attempt to cast it as an integer type for analysis. Furthermore, several other features are non-numeric, and we would need to parse them for the machine learning algorithms to process. There are also values with the same intrinsic value but different representation e.g. "Low" vs "L", and so we would need to pre-process these before discrete categorisation.

# %% [markdown]
# ## Broad Description of the initial column categories
# Running .describe() below gives us a numerical understanding of our data, while looking preemptively at a sample of 10 rows of the data can give us some intuition and understanding of the representation, so that we know how to proceed to categorize.
#
# ### In Summary:
# Total of 14 sub-categories, 9 numerical sub-categories

# %%
train.columns.values
# Out:
# array(['ID', 'Survive', 'Gender', 'Smoke', 'Diabetes', 'Age',
#        'Ejection Fraction', 'Sodium', 'Creatinine', 'Platelets',
#        'Creatine phosphokinase', 'Blood Pressure', 'Hemoglobin', 'Height',
#        'Weight', 'Favorite color'], dtype=object)

# %%
train.describe()
# Out:
#                 Age        Sodium    Creatinine      Platelets  \
# count  12000.000000  12000.000000  11599.000000   12000.000000
# mean      57.385083    136.589500      1.413809  263476.832639
# std       23.363200      4.394231      1.057891   98458.992524
# min      -95.000000    113.000000      0.500000   25100.000000
# 25%       50.000000    134.000000      0.900000  211000.000000
# 50%       60.000000    137.000000      1.100000  262000.000000
# 75%       69.000000    140.000000      1.400000  304000.000000
# max       95.000000    148.000000      9.400000  850000.000000
#
#        Creatine phosphokinase  Blood Pressure    Hemoglobin        Height  \
# count            12000.000000    12000.000000  12000.000000  12000.000000
# mean               579.708167      103.744833     12.889833    159.384083
# std                959.200017       39.792177      2.499380     17.316564
# min                 23.000000       40.000000      9.000000    130.000000
# 25%                115.000000       70.000000     10.700000    144.000000
# 50%                249.000000      100.000000     12.700000    160.000000
# 75%                582.000000      137.000000     15.100000    174.000000
# max               7861.000000      179.000000     17.500000    189.000000
#
#              Weight
# count  12000.000000
# mean      69.344417
# std       25.218382
# min       19.000000
# 25%       50.000000
# 50%       66.000000
# 75%       87.000000
# max      141.000000

# %% [markdown]
# ### Overview of Features
# 1. ID (object) -> the unique alphanumeric sequence to identify patients. The non-indexed nature of the ID is likely an  obfuscation to deidentify patients.
#
# 2. Survive (object) -> { No: "0", Yes: "1"} on whether a patient survives coronary artery disease at time of test. We will need to cast this as type(int) later on.
#
# 3. Gender (object) -> { "Male", "Female" } dictates the gender of the patient.
#
# 4. Smoke (object) -> { "Yes", "No" } if the patient is a smoker or not.
#
# 5. Diabetes (object) -> { "Normal", "Pre-diabetic", "Diabetes" } non-continuous data, but could it be on a continuum?
#
# 6. Age (int64) -> continuous, need to categorise. There are apparently some negative numbers too (likely a typographical error).
#
# 7. Ejection Fraction (object) -> { "Low", "High" } describes the strength of the heart
#
# 8. Sodium (int | mg/dL) -> 113 (min) to 148 (max)
#
# 9. Creatinine (float | mEq/L) -> 0.5 (min) to 9.4 (max)
#
# 10. Platelets (float | platelets/mL) -> 25100 (min) to 850000 (max)
#
# 11. Creatine phosphokinase (int | mcg/L) -> 23 (min) to 7861 (max)
#
# 12. Blood Pressure	(int | mmHg) -> 40 (min) to 179 (max)
#
# 13. Hemoglobin	(float | g/dL) -> 9 (min) to 17.5 (max)
#
# 14. Height in cm (int) -> 130 (min) to 189 (max)
#
# 15. Weight in kg (int)	-> 25.298 (min) to 141 (max)
#
# 16. Favorite color -> top is blue, 6 unique colors {black, blue, green, red, white, yellow} (does this matter?!)

# %% [markdown]
# We will first check which values are missing.

# %%
total = train.isnull().sum().sort_values(ascending=False)
proportion = train.isnull().sum()/train.isnull().count()*100
proportion_sorted = (round(proportion, 1)).sort_values(ascending=False)
missing = pd.concat([total, proportion_sorted], axis=1, keys=['Total', '%'])
missing.head(3)
# Out:
#                 Total    %
# Creatinine        401  3.3
# Favorite color      0  0.0
# Weight              0  0.0

# %% [markdown]
# The creatinine feature has ~390 values missing, but since it's a small proportion (around 3%) we will attempt to impute it using common figures. We will do this later.

# %% [markdown]
# ## Data Cleaning
#
# **1. Key Feature**
#
# We will first look at our key feature "Survive" and denormalize it to an integer feature.

# %%
data = [train, test]
# ensure that the binary values are inputted as strings
for ds in data:
    ds["Survive"] = ds["Survive"].replace('No', 0)
    ds["Survive"] = ds["Survive"].replace('Yes', 1)
    ds["Survive"] = ds["Survive"].astype(int)
train["Survive"].describe()
# Out:
# count    12000.000000
# mean         0.324917
# std          0.468363
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
# Name: Survive, dtype: float64

# %% [markdown]
# **2. Effects of age & gender on survival**

# %%
# there are negative values, we need absolute all the values

train["Age"] = abs(train["Age"])
train["Age"].describe()
# Out:
# count    12000.000000
# mean        60.816583
# std         11.840451
# min         40.000000
# 25%         51.000000
# 50%         60.000000
# 75%         70.000000
# max         95.000000
# Name: Age, dtype: float64

# %% [markdown]
# The proportion of females suffering from coronary artery disease is roughly half of that of males (35% against 65%). We can see that both males and females have low mortality rates below the age of 70. Men have higer probabilities of survival past the age of 70, whereas women enjoy greater probabilities at the age of 60.

# %%
#     # see proportion of males against females
male_count = train[train["Gender"] == "Male"].count()["Gender"]
male_proportion = (male_count / train.count() * 100)["Gender"]
female_count = train[train["Gender"] == "Female"].count()["Gender"]
female_proportion = 100 - male_proportion

print("Males:", male_proportion, male_count)
print("Females:", female_proportion, female_count )
# Out:
# Males: 64.89166666666667 7787
# Females: 35.108333333333334 4213

# %%
train
# Out:
#            ID  Survive  Gender Smoke      Diabetes  Age Ejection Fraction  \
# 8081   8BPXQO        0  Female    No      Diabetes   45            Normal
# 2865   H2SX52        0    Male   Yes      Diabetes   51               Low
# 12834  C96E1U        0    Male    No  Pre-diabetes   60               Low
# 2983   579Q5K        1    Male    No      Diabetes   65               Low
# 12119  U7XTEV        1    Male   Yes        Normal   72               Low
# ...       ...      ...     ...   ...           ...  ...               ...
# 14075  J54ZHY        0  Female    No        Normal   70               Low
# 11073  KJPSL8        1    Male    No        Normal   45               Low
# 8396   KMYXDU        0    Male   Yes        Normal   63               Low
# 4143   12H5EA        0  Female    No  Pre-diabetes   65            Normal
# 6368   W2NJEP        0    Male    No        Normal   55               Low
#
#        Sodium  Creatinine  Platelets  Creatine phosphokinase  Blood Pressure  \
# 8081      138         0.8  742000.00                    2060              58
# 2865      136         1.5  263358.03                     582             103
# 12834     137         2.3  305000.00                    2656              94
# 2983      129         1.4  198000.00                     258              49
# 12119     139         1.7  338000.00                     943             174
# ...       ...         ...        ...                     ...             ...
# 14075     136         1.7  293000.00                      69              73
# 11073     135         1.6  126000.00                     582             126
# 8396      137         0.9  448000.00                     582             113
# 4143      140         0.9  203000.00                     113             164
# 6368      137         1.3  263000.00                     748             100
#
#        Hemoglobin  Height  Weight Favorite color
# 8081         13.2     131      21          white
# 2865         11.4     156      62           blue
# 12834        16.2     180     120          green
# 2983         11.8     143      34          green
# 12119        10.8     147      62           blue
# ...           ...     ...     ...            ...
# 14075        16.5     184     110            red
# 11073        13.3     133      39            red
# 8396         11.4     148      61         yellow
# 4143         11.1     132      53          black
# 6368         15.9     184     106           blue
#
# [12000 rows x 16 columns]

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize = (10,4))
female = train[train["Gender"] == "Female"]
male = train[train["Gender"] == "Male"]

ax = sns.histplot(data = female[female["Survive"] == 1], x = "Age", bins = 20, ax = axes[0], element="step", color="green",label = "Survived")
ax = sns.histplot(data = female[female["Survive"] == 0], x = "Age", bins= 20, ax = axes[0], element="step", color="gray", label="Did not survive")
ax.legend()
ax.set_title("Female")

ax1 = sns.histplot(data = male[male["Survive"] == 1], x = "Age", bins = 20, ax = axes[1], element="step", color="green", label = "Survived")
ax1 = sns.histplot(data = male[male["Survive"] == 0], x = "Age", bins= 20, ax = axes[1], element="step",color="gray", label="Did not survive")
ax1.legend()
ax1.set_title("Male")
# Out:
# Text(0.5, 1.0, 'Male')

# %%
data = [train, test]
gender_map = {"Male": 1, "Female": 0}

for ds in data:
    # map male to 1 and females to 0
    ds["Gender"] = ds["Gender"].map(gender_map)

# %% [markdown]
# **3. Height and Weight / BMI**
#
# Since height and weight are correlated, there seems to be more value in analysing the data from the perspective of a Body Mass Index (BMI), which is formulated from the weight (kg) divided by the square of the height (m) of the individual. This allows us for better classification under the Obesity scale.

# %%
data = [train, test]

for ds in data:
    ds["BMI"] = (ds["Weight"] / (ds["Height"] / 100 )**2)

# %% [markdown]
# **Smoking**

# %%
data = [train, test]
smoke_map = { "Yes": 1, "No": 0}

for ds in data:
    ds["Smoke"] = ds["Smoke"].replace("YES", "Yes")
    ds["Smoke"] = ds["Smoke"].replace("NO","No")
    ds["Smoke"] = ds["Smoke"].map(smoke_map)
train["Smoke"].value_counts()
# Out:
# 0    8095
# 1    3905
# Name: Smoke, dtype: int64

# %% [markdown]
# **Diabetes**

# %%
data = [train, test]
diabetes_map = { "Normal": 0, "Pre-diabetes": 1, "Diabetes": 2 }

for ds in data:
    ds["Diabetes"] = ds["Diabetes"].map(diabetes_map)
train["Diabetes"].value_counts()
# Out:
# 0    6998
# 1    2512
# 2    2490
# Name: Diabetes, dtype: int64

# %% [markdown]
# **Ejection Fraction**

# %%
data = [train, test]
ejection_map = { "Low": 0, "Normal": 1, "High": 2 }
for ds in data:
    ds["Ejection Fraction"] = ds["Ejection Fraction"].replace("L", "Low")
    ds["Ejection Fraction"] = ds["Ejection Fraction"].replace("N", "Normal")
    ds["Ejection Fraction"] = ds["Ejection Fraction"].replace("H", "High")
    ds["Ejection Fraction"] = ds["Ejection Fraction"].map(ejection_map)
train["Ejection Fraction"].value_counts()
# Out:
# 0    10592
# 1     1362
# 2       46
# Name: Ejection Fraction, dtype: int64

# %% [markdown]
# ### Colours
# We can find the enum type of colors by grouping them together and counting. Intuitively, one can assume safely that colors should have no correlation with the diagnosis and survival rate of a patient facing coronary artery disease.

# %%
train.groupby("Favorite color").count()
# Out:
#                   ID  Survive  Gender  Smoke  Diabetes   Age  \
# Favorite color
# black           2011     2011    2011   2011      2011  2011
# blue            2008     2008    2008   2008      2008  2008
# green           1979     1979    1979   1979      1979  1979
# red             2014     2014    2014   2014      2014  2014
# white           1962     1962    1962   1962      1962  1962
# yellow          2026     2026    2026   2026      2026  2026
#
#                 Ejection Fraction  Sodium  Creatinine  Platelets  \
# Favorite color
# black                        2011    2011        1951       2011
# blue                         2008    2008        1941       2008
# green                        1979    1979        1924       1979
# red                          2014    2014        1942       2014
# white                        1962    1962        1890       1962
# yellow                       2026    2026        1951       2026
#
#                 Creatine phosphokinase  Blood Pressure  Hemoglobin  Height  \
# Favorite color
# black                             2011            2011        2011    2011
# blue                              2008            2008        2008    2008
# green                             1979            1979        1979    1979
# red                               2014            2014        2014    2014
# white                             1962            1962        1962    1962
# yellow                            2026            2026        2026    2026
#
#                 Weight   BMI
# Favorite color
# black             2011  2011
# blue              2008  2008
# green             1979  1979
# red               2014  2014
# white             1962  1962
# yellow            2026  2026

# %%
color_map = { "black": 0,"blue": 1, "green": 2,"red": 3, "white": 4, "yellow": 5}
data = [train, test]

for ds in data:
    ds["Favorite color"] = ds["Favorite color"].map(color_map)
    
train["Favorite color"].value_counts()
# Out:
# 5    2026
# 3    2014
# 0    2011
# 1    2008
# 2    1979
# 4    1962
# Name: Favorite color, dtype: int64

# %% [markdown]
# ## Creating Categories

# %%
train
# Out:
#            ID  Survive  Gender  Smoke  Diabetes  Age  Ejection Fraction  \
# 11506  UIUR36        1       0      1         1   50                  0
# 1001   UAHHVU        0       1      0         0   70                  0
# 10417  GS5S2W        0       1      0         0   64                  1
# 582    PAG8AH        0       0      0         1   65                  1
# 2174   DQU4HO        0       1      1         1   70                  0
# ...       ...      ...     ...    ...       ...  ...                ...
# 3879   APPF24        1       1      0         1   65                  0
# 2837   50I4Y1        0       1      0         0   64                  0
# 9217   XY64P8        0       1      1         0   42                  0
# 14586  B88BYV        1       1      1         1   65                  0
# 11554  8O9ZBJ        1       0      0         1   60                  0
#
#        Sodium  Creatinine  Platelets  Creatine phosphokinase  Blood Pressure  \
# 11506     136        1.20   153000.0                     124             143
# 1001      132        1.20   173000.0                     232             113
# 10417     137        1.00   242000.0                    1610              43
# 582       140        0.90   203000.0                     113             165
# 2174      136        1.00   389000.0                     212             139
# ...       ...         ...        ...                     ...             ...
# 3879      135        1.83   497000.0                     113              63
# 2837      135        2.40   246000.0                     143              66
# 9217      140        1.00   226000.0                    5209              47
# 14586     136        1.20   265000.0                     395             114
# 11554     144        2.10   365000.0                    1896              61
#
#        Hemoglobin  Height  Weight  Favorite color        BMI
# 11506        15.2     142      74               4  36.699068
# 1001         12.8     143      39               0  19.071837
# 10417        17.0     176      89               1  28.731921
# 582          10.2     140      60               4  30.612245
# 2174         15.1     134      38               1  21.162843
# ...           ...     ...     ...             ...        ...
# 3879         15.1     153      78               3  33.320518
# 2837         17.5     147      40               3  18.510806
# 9217         13.9     176      97               5  31.314566
# 14586        14.1     135      45               1  24.691358
# 11554        12.6     161      59               5  22.761468
#
# [12000 rows x 17 columns]

# %% [markdown]
# **BMI**

# %%
data = [train, test]

for ds in data:
    
    ds.loc[ds["BMI"] <= 18.5, "BMI"] = 0 #underweight
    ds.loc[(ds["BMI"] > 18.5) & (ds["BMI"] <= 24.9), "BMI"] = 1 #healthy
    ds.loc[(ds["BMI"] > 24.9) & (ds["BMI"] <= 29.9), "BMI"] = 2 #overweight
    ds.loc[ds["BMI"] > 29.9, "BMI"] = 3 #obese
    ds["BMI"] = ds["BMI"].astype(int)

    
train["BMI"].value_counts()
# Out:
# 3    5090
# 1    2837
# 2    2208
# 0    1865
# Name: BMI, dtype: int64

# %% [markdown]
# **Age**

# %%
train[train["Age"]<0]
# Out:
# Empty DataFrame
# Columns: [ID, Survive, Gender, Smoke, Diabetes, Age, Ejection Fraction, Sodium, Creatinine, Platelets, Creatine phosphokinase, Blood Pressure, Hemoglobin, Height, Weight, Favorite color, BMI]
# Index: []

# %%
train["Age Group"] = pd.qcut(train["Age"], 4)
train["Age Group"].value_counts()
# Out:
# (51.0, 60.0]      3515
# (60.0, 70.0]      3323
# (39.999, 51.0]    3104
# (70.0, 95.0]      2058
# Name: Age Group, dtype: int64

# %%
data = [train, test]

for ds in data:
    ds.loc[ds["Age"] <= 51, "Age"] = 0
    ds.loc[(ds["Age"] > 51) & (ds["Age"] <= 60), "Age"] = 1
    ds.loc[(ds["Age"] > 60) & (ds["Age"] <= 70), "Age"] = 2
    ds.loc[ds["Age"] > 70, "Age"] = 3
    ds["Age"] = ds["Age"].astype(int)

# %% [markdown]
# **Sodium**

# %%
train["Sodium"].describe()
# Out:
# count    12000.000000
# mean       136.589500
# std          4.394231
# min        113.000000
# 25%        134.000000
# 50%        137.000000
# 75%        140.000000
# max        148.000000
# Name: Sodium, dtype: float64

# %%
train["Sodium Group"] = pd.qcut(train["Sodium"], 5)
train["Sodium Group"].value_counts()
# Out:
# (112.999, 134.0]    3380
# (136.0, 138.0]      2481
# (138.0, 140.0]      2286
# (134.0, 136.0]      2193
# (140.0, 148.0]      1660
# Name: Sodium Group, dtype: int64

# %%
data = [train, test]

for ds in data:
    ds.loc[ds["Sodium"] <= 134, "Sodium"] = 0
    ds.loc[(ds["Sodium"] > 134) & (ds["Sodium"] <= 136), "Sodium"] = 1
    ds.loc[(ds["Sodium"] > 136) & (ds["Sodium"] <= 138), "Sodium"] = 2
    ds.loc[(ds["Sodium"] > 138) & (ds["Sodium"] <= 140), "Sodium"] = 3
    ds.loc[ds["Sodium"] > 140, "Sodium"] = 4
    ds["Sodium"] = ds["Sodium"].astype(int)

# %% [markdown]
# **Creatinine**

# %% [markdown]
# Remember that for creatinine, we had ~380 missing values that we need to impute. We will fill the missing values with random numbers within +-1 standard deviation from the mean.

# %%
data = [train, test]

for ds in data:
    mean = train["Creatinine"].mean()
    std = test["Creatinine"].std()
    null_values = ds["Creatinine"].isnull().sum()
    
    random_creatinine = np.random.randint( mean-std, mean+std, size = null_values)
    
    creatinine_copy = ds["Creatinine"].copy()
    creatinine_copy[np.isnan(creatinine_copy)] = random_creatinine
    ds["Creatinine"] = creatinine_copy

train["Creatinine"].isnull().sum()
# Out:
# 0

# %%
train["Creatinine Group"] = pd.qcut(train["Creatinine"], 4)
train["Creatinine Group"].value_counts()
# Out:
# (0.9, 1.1]       3398
# (-0.001, 0.9]    3252
# (1.4, 9.4]       2882
# (1.1, 1.4]       2468
# Name: Creatinine Group, dtype: int64

# %%
data = [train, test]

for ds in data:
    ds.loc[ds["Creatinine"] <= 0.9, "Creatinine"] = 0
    ds.loc[(ds["Creatinine"] > 0.9) & (ds["Creatinine"] <= 1.1), "Creatinine"] = 1
    ds.loc[(ds["Creatinine"] > 1.1) & (ds["Creatinine"] <= 1.4), "Creatinine"] = 2
    ds.loc[ds["Creatinine"] > 1.4, "Creatinine"] = 3
    ds["Creatinine"] = ds["Creatinine"].astype(int)

# %% [markdown]
# **Platelets**

# %%
train["Platelets Group"] = pd.qcut(train["Platelets"], 4)
train["Platelets Group"].value_counts()
# Out:
# (25099.999, 211000.0]    3029
# (211000.0, 262000.0]     3004
# (262000.0, 304000.0]     2992
# (304000.0, 850000.0]     2975
# Name: Platelets Group, dtype: int64

# %%
data = [train, test]

for ds in data:
    ds.loc[ds["Platelets"] <= 211000, "Platelets"] = 0
    ds.loc[(ds["Platelets"] > 211000) & (ds["Platelets"] <= 262000), "Platelets"] = 1
    ds.loc[(ds["Platelets"] > 262000) & (ds["Platelets"] <= 304000), "Platelets"] = 2
    ds.loc[ds["Platelets"] > 304000, "Platelets"] = 3
    ds["Platelets"] = ds["Platelets"].astype(int)

# %% [markdown]
# **Creatine phosphokinase**

# %%
train["CP Group"] = pd.qcut(train["Creatine phosphokinase"], 5)
train["CP Group"].value_counts()
# Out:
# (400.0, 618.0]     2439
# (22.999, 101.0]    2423
# (176.0, 400.0]     2401
# (101.0, 176.0]     2378
# (618.0, 7861.0]    2359
# Name: CP Group, dtype: int64

# %%
data = [train, test]

for ds in data:
    ds.loc[ds["Creatine phosphokinase"] <= 99.0, "Creatine phosphokinase"] = 0
    ds.loc[(ds["Creatine phosphokinase"] > 99.0) & (ds["Creatine phosphokinase"] <= 180.0), "Creatine phosphokinase"] = 1
    ds.loc[(ds["Creatine phosphokinase"] > 180.0) & (ds["Creatine phosphokinase"] <= 418.0), "Creatine phosphokinase"] = 2
    ds.loc[(ds["Creatine phosphokinase"] > 418.0) & (ds["Creatine phosphokinase"] <= 646.0), "Creatine phosphokinase"] = 3
    ds.loc[ds["Creatine phosphokinase"] > 646.0, "Creatine phosphokinase"] = 4
    ds["Creatine phosphokinase"] = ds["Creatine phosphokinase"].astype(int)

# %% [markdown]
# **Blood Pressure**

# %%
train["BP Group"] = pd.qcut(train["Blood Pressure"], 4)
train["BP Group"].value_counts()
# Out:
# (39.999, 70.0]    3027
# (100.0, 137.0]    3006
# (137.0, 179.0]    2984
# (70.0, 100.0]     2983
# Name: BP Group, dtype: int64

# %%
data = [train, test]

for ds in data:
    ds.loc[ds["Blood Pressure"] <= 70, "Blood Pressure"] = 0
    ds.loc[(ds["Blood Pressure"] > 70) & (ds["Blood Pressure"] <= 100), "Blood Pressure"] = 1
    ds.loc[(ds["Blood Pressure"] > 100) & (ds["Blood Pressure"] <= 136), "Blood Pressure"] = 2
    ds.loc[ds["Blood Pressure"] > 136, "Blood Pressure"] = 3
    ds["Blood Pressure"] = ds["Blood Pressure"].astype(int)

# %% [markdown]
# **Hemoglobin**

# %%
train["Hemoglobin Group"] = pd.qcut(train["Hemoglobin"], 4)
train["Hemoglobin Group"].value_counts()
# Out:
# (8.999, 10.7]    3143
# (12.7, 15.1]     3001
# (10.7, 12.7]     2943
# (15.1, 17.5]     2913
# Name: Hemoglobin Group, dtype: int64

# %%
data = [train, test]

for ds in data:
    ds.loc[ds["Hemoglobin"] <= 10.7, "Hemoglobin"] = 0
    ds.loc[(ds["Hemoglobin"] > 10.7) & (ds["Hemoglobin"] <= 12.7), "Hemoglobin"] = 1
    ds.loc[(ds["Hemoglobin"] > 12.7) & (ds["Hemoglobin"] <= 15.1), "Hemoglobin"] = 2
    ds.loc[ds["Hemoglobin"] > 15.1, "Hemoglobin"] = 3
    ds["Hemoglobin"] = ds["Hemoglobin"].astype(int)

# %%
data = [train, test]
train = train.drop(columns=["ID","Sodium Group", "Height", "Weight", "Age Group", "Creatinine Group", "Platelets Group", "CP Group","BP Group","Hemoglobin Group"])

# %%
train
# Out:
#        Survive  Gender  Smoke  Diabetes  Age  Ejection Fraction  Sodium  \
# 11506        1       0      1         1    0                  0       1
# 1001         0       1      0         0    2                  0       0
# 10417        0       1      0         0    2                  1       2
# 582          0       0      0         1    2                  1       3
# 2174         0       1      1         1    2                  0       1
# ...        ...     ...    ...       ...  ...                ...     ...
# 3879         1       1      0         1    2                  0       1
# 2837         0       1      0         0    2                  0       1
# 9217         0       1      1         0    0                  0       3
# 14586        1       1      1         1    2                  0       1
# 11554        1       0      0         1    1                  0       4
#
#        Creatinine  Platelets  Creatine phosphokinase  Blood Pressure  \
# 11506           3          0                       1               3
# 1001            3          0                       2               2
# 10417           1          1                       4               0
# 582             0          0                       1               3
# 2174            1          3                       2               3
# ...           ...        ...                     ...             ...
# 3879            3          3                       1               0
# 2837            3          1                       1               0
# 9217            1          1                       4               0
# 14586           3          2                       2               2
# 11554           3          3                       4               0
#
#        Hemoglobin  Favorite color  BMI
# 11506           3               4    3
# 1001            2               0    1
# 10417           3               1    2
# 582             0               4    3
# 2174            2               1    1
# ...           ...             ...  ...
# 3879            2               3    3
# 2837            3               3    1
# 9217            2               5    3
# 14586           2               1    1
# 11554           1               5    1
#
# [12000 rows x 14 columns]

# %%
test = test.drop(columns=["ID","Height","Weight"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-483-1e5eb74c19d4> in <module>
# ----> 1 test = test.drop(columns=["ID","Height","Weight"])
#       2 test
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    3919                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3920             else:
# -> 3921                 new_axis = axis.drop(labels, errors=errors)
#    3922             result = self.reindex(**{axis_name: new_axis})
#    3923
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    5280         if mask.any():
#    5281             if errors != "ignore":
# -> 5282                 raise KeyError(f"{labels[mask]} not found in axis")
#    5283             indexer = indexer[~mask]
#    5284         return self.delete(indexer)
#
# KeyError: "['ID' 'Height' 'Weight'] not found in axis"

# %%
test
# Out:
#        Survive  Gender  Smoke  Diabetes  Age  Ejection Fraction  Sodium  \
# 14443        1       1      0         1    2                  0       1
# 8384         1       0      0         2    1                  0       0
# 3592         1       0      0         0    2                  0       3
# 6583         0       0      0         0    0                  0       3
# 3641         1       0      0         2    0                  0       0
# ...        ...     ...    ...       ...  ...                ...     ...
# 6133         1       1      0         0    1                  0       1
# 14554        1       0      0         2    3                  0       4
# 14433        0       1      1         0    1                  0       3
# 8632         0       0      0         2    2                  1       3
# 6045         1       1      1         2    2                  0       1
#
#        Creatinine  Platelets  Creatine phosphokinase  Blood Pressure  \
# 14443           3          3                       1               2
# 8384            3          0                       0               2
# 3592            1          1                       1               2
# 6583            1          0                       0               1
# 3641            3          0                       3               0
# ...           ...        ...                     ...             ...
# 6133            3          0                       1               1
# 14554           1          3                       4               3
# 14433           0          3                       4               1
# 8632            0          0                       1               3
# 6045            3          2                       2               2
#
#        Hemoglobin  Favorite color  BMI
# 14443           3               5    3
# 8384            0               1    3
# 3592            0               3    3
# 6583            1               5    2
# 3641            1               4    3
# ...           ...             ...  ...
# 6133            0               1    3
# 14554           0               2    3
# 14433           3               0    2
# 8632            1               3    3
# 6045            3               2    1
#
# [3000 rows x 14 columns]

# %% [markdown]
# ## Machine Learning Models

# %%
X_train = train.drop("Survive", axis=1)
Y_train = train["Survive"]
X_test = test.drop("Survive",axis=1).copy()

X_train
# Out:
#        Gender  Smoke  Diabetes  Age  Ejection Fraction  Sodium  Creatinine  \
# 11506       0      1         1    0                  0       1           3
# 1001        1      0         0    2                  0       0           3
# 10417       1      0         0    2                  1       2           1
# 582         0      0         1    2                  1       3           0
# 2174        1      1         1    2                  0       1           1
# ...       ...    ...       ...  ...                ...     ...         ...
# 3879        1      0         1    2                  0       1           3
# 2837        1      0         0    2                  0       1           3
# 9217        1      1         0    0                  0       3           1
# 14586       1      1         1    2                  0       1           3
# 11554       0      0         1    1                  0       4           3
#
#        Platelets  Creatine phosphokinase  Blood Pressure  Hemoglobin  \
# 11506          0                       1               3           3
# 1001           0                       2               2           2
# 10417          1                       4               0           3
# 582            0                       1               3           0
# 2174           3                       2               3           2
# ...          ...                     ...             ...         ...
# 3879           3                       1               0           2
# 2837           1                       1               0           3
# 9217           1                       4               0           2
# 14586          2                       2               2           2
# 11554          3                       4               0           1
#
#        Favorite color  BMI
# 11506               4    3
# 1001                0    1
# 10417               1    2
# 582                 4    3
# 2174                1    1
# ...               ...  ...
# 3879                3    3
# 2837                3    1
# 9217                5    3
# 14586               1    1
# 11554               5    1
#
# [12000 rows x 13 columns]

# %% [markdown]
# ### Stochastic Gradient Descent

# %%
sgd = linear_model.SGDClassifier(max_iter=5, tol=None)
sgd.fit(X_train, Y_train)

Y_pred = sgd.predict(X_test)

acc_sgd = round(sgd.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### Random Forest

# %%
random_forest = RandomForestClassifier(n_estimators=100)
random_forest.fit(X_train, Y_train)

Y_prediction = random_forest.predict(X_test)

acc_random_forest = round(random_forest.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### Logistic Regression

# %%
logreg = LogisticRegression()
logreg.fit(X_train, Y_train)

Y_pred = logreg.predict(X_test)

acc_log = round(logreg.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### k Nearest Neighbour

# %%
knn = KNeighborsClassifier(n_neighbors = 3) 
knn.fit(X_train, Y_train)  

Y_pred = knn.predict(X_test)

acc_knn = round(knn.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### Gaussian Naive Bayes

# %%
gaussian = GaussianNB() 
gaussian.fit(X_train, Y_train)

Y_pred = gaussian.predict(X_test)  

acc_gaussian = round(gaussian.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### Support Vector Machine

# %%
linear_svc = SVC()
linear_svc.fit(X_train, Y_train)

Y_pred = linear_svc.predict(X_test)

acc_linear_svc = round(linear_svc.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### Decision Tree

# %%
decision_tree = DecisionTreeClassifier() 
decision_tree.fit(X_train, Y_train)  

Y_pred = decision_tree.predict(X_test)  

acc_decision_tree = round(decision_tree.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ### Perceptron

# %%
perceptron = Perceptron(max_iter=10)
perceptron.fit(X_train, Y_train)

Y_pred = perceptron.predict(X_test)

acc_perceptron = round(perceptron.score(X_train, Y_train) * 100, 2)

# %% [markdown]
# ## Which is the best model?

# %%
results = pd.DataFrame({
    'Model': ['Support Vector Machines', 'KNN', 'Logistic Regression', 
              'Random Forest', 'Naive Bayes', 'Perceptron', 
              'Stochastic Gradient Decent', 
              'Decision Tree'],
    'Score': [acc_linear_svc, acc_knn, acc_log, 
              acc_random_forest, acc_gaussian, acc_perceptron, 
              acc_sgd, acc_decision_tree]})
result_df = results.sort_values(by='Score', ascending=False)
result_df = result_df.set_index('Score')
result_df.head(9)
# Out:
#                              Model
# Score
# 100.00               Random Forest
# 100.00               Decision Tree
# 99.82                          KNN
# 94.95      Support Vector Machines
# 76.82          Logistic Regression
# 76.16                  Naive Bayes
# 72.14                   Perceptron
# 64.35   Stochastic Gradient Decent

# %%
from sklearn.model_selection import cross_val_score

rf = RandomForestClassifier(n_estimators=100)
scores = cross_val_score(rf, X_train, Y_train, cv=10, scoring = "accuracy")

print("Scores:", scores)
print("Mean:", scores.mean())
print("Standard Deviation:", scores.std())
# Out:
# Scores: [1.         0.99916667 1.         0.99833333 1.         1.
#  0.99916667 1.         1.         1.        ]
# Mean: 0.9996666666666666
# Standard Deviation: 0.0005527707983925794
